# %% [markdown]
# # IMPORT LIBRARIES/DATASETS

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import pickle
import random

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
x_train, y_train = train['features'], train['labels']
x_validation, y_validation = valid['features'], valid['labels']
x_test, y_test = test['features'], test['labels']

# %%
x_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # PERFORM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(x_train))
plt.imshow(x_train[i])
y_train[i]
# Out:
# 34

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 10
L_grid = 10

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 5 x 5 matrix into 25 array

n_training = len(x_train) # get the length of the training dataset

# Select a random number from 0 to n_training
# create evenly spaces variables 
for i in np.arange(0, W_grid * L_grid):
    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow(x_train[index])
    axes[i].set_title(y_train[index], fontsize=15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
x_train, y_train = shuffle(x_train, y_train)

# %%
x_train_gray = np.sum(x_train/3, axis=3, keepdims=True)
x_test_gray = np.sum(x_test/3, axis=3, keepdims=True)
x_validation_gray = np.sum(x_validation/3, axis=3, keepdims=True)

# %%
x_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
x_train_gray_norm = (x_train_gray - 128)/128
x_test_gray_norm = (x_test_gray - 128)/128
x_validation_gray_norm = (x_validation_gray - 128)/128

# %%
x_train_gray_norm
# Out:
# array([[[[-0.59895833],
#          [-0.59114583],
#          [-0.5859375 ],
#          ...,
#          [-0.62239583],
#          [-0.625     ],
#          [-0.625     ]],
#
#         [[-0.61458333],
#          [-0.60677083],
#          [-0.60677083],
#          ...,
#          [-0.63020833],
#          [-0.63541667],
#          [-0.62760417]],
#
#         [[-0.61979167],
#          [-0.61979167],
#          [-0.62239583],
#          ...,
#          [-0.62760417],
#          [-0.6328125 ],
#          [-0.62239583]],
#
#         ...,
#
#         [[-0.7109375 ],
#          [-0.70833333],
#          [-0.70052083],
#          ...,
#          [-0.75520833],
#          [-0.73958333],
#          [-0.7265625 ]],
#
#         [[-0.70833333],
#          [-0.70572917],
#          [-0.71354167],
#          ...,
#          [-0.74739583],
#          [-0.73177083],
#          [-0.72135417]],
#
#         [[-0.72395833],
#          [-0.72395833],
#          [-0.72916667],
#          ...,
#          [-0.74739583],
#          [-0.72916667],
#          [-0.73697917]]],
#
#
#        [[[-0.75      ],
#          [-0.74739583],
#          [-0.75520833],
#          ...,
#          [-0.65625   ],
#          [-0.63541667],
#          [-0.6171875 ]],
#
#         [[-0.75      ],
#          [-0.76041667],
#          [-0.76822917],
#          ...,
#          [-0.70572917],
#          [-0.703125  ],
#          [-0.72916667]],
#
#         [[-0.76041667],
#          [-0.76041667],
#          [-0.76302083],
#          ...,
#          [-0.75520833],
#          [-0.765625  ],
#          [-0.78645833]],
#
#         ...,
#
#         [[-0.78645833],
#          [-0.78645833],
#          [-0.79427083],
#          ...,
#          [-0.796875  ],
#          [-0.80208333],
#          [-0.79947917]],
#
#         [[-0.78645833],
#          [-0.78645833],
#          [-0.77864583],
#          ...,
#          [-0.796875  ],
#          [-0.80208333],
#          [-0.80208333]],
#
#         [[-0.78385417],
#          [-0.78125   ],
#          [-0.78645833],
#          ...,
#          [-0.79947917],
#          [-0.796875  ],
#          [-0.79427083]]],
#
#
#        [[[-0.61458333],
#          [-0.59635417],
#          [-0.61979167],
#          ...,
#          [-0.36458333],
#          [-0.39583333],
#          [-0.38802083]],
#
#         [[-0.5625    ],
#          [-0.50520833],
#          [-0.53125   ],
#          ...,
#          [-0.3671875 ],
#          [-0.4375    ],
#          [-0.453125  ]],
#
#         [[-0.28645833],
#          [-0.12760417],
#          [ 0.11979167],
#          ...,
#          [-0.33333333],
#          [-0.40104167],
#          [-0.52604167]],
#
#         ...,
#
#         [[-0.5625    ],
#          [-0.4765625 ],
#          [-0.53125   ],
#          ...,
#          [-0.4140625 ],
#          [-0.42708333],
#          [-0.48958333]],
#
#         [[-0.55989583],
#          [-0.5       ],
#          [-0.55208333],
#          ...,
#          [-0.34895833],
#          [-0.34635417],
#          [-0.53125   ]],
#
#         [[-0.53125   ],
#          [-0.6015625 ],
#          [-0.65364583],
#          ...,
#          [-0.45833333],
#          [-0.35416667],
#          [-0.4921875 ]]],
#
#
#        ...,
#
#
#        [[[-0.70833333],
#          [-0.71354167],
#          [-0.64583333],
#          ...,
#          [-0.55989583],
#          [-0.7421875 ],
#          [-0.80989583]],
#
#         [[-0.73697917],
#          [-0.671875  ],
#          [-0.65885417],
#          ...,
#          [-0.68489583],
#          [-0.7421875 ],
#          [-0.80729167]],
#
#         [[-0.58072917],
#          [-0.58333333],
#          [-0.6796875 ],
#          ...,
#          [-0.7578125 ],
#          [-0.77083333],
#          [-0.8046875 ]],
#
#         ...,
#
#         [[-0.72135417],
#          [-0.68229167],
#          [-0.64322917],
#          ...,
#          [-0.6484375 ],
#          [-0.7421875 ],
#          [-0.78125   ]],
#
#         [[-0.61197917],
#          [-0.69010417],
#          [-0.6484375 ],
#          ...,
#          [-0.6640625 ],
#          [-0.72135417],
#          [-0.64322917]],
#
#         [[-0.67447917],
#          [-0.67708333],
#          [-0.62239583],
#          ...,
#          [-0.54427083],
#          [-0.6484375 ],
#          [-0.60677083]]],
#
#
#        [[[-0.79166667],
#          [-0.78385417],
#          [-0.79947917],
#          ...,
#          [-0.88020833],
#          [-0.875     ],
#          [-0.88020833]],
#
#         [[-0.79947917],
#          [-0.8046875 ],
#          [-0.81510417],
#          ...,
#          [-0.87239583],
#          [-0.87760417],
#          [-0.88020833]],
#
#         [[-0.80729167],
#          [-0.80729167],
#          [-0.81510417],
#          ...,
#          [-0.87239583],
#          [-0.875     ],
#          [-0.88020833]],
#
#         ...,
#
#         [[-0.88020833],
#          [-0.88020833],
#          [-0.88541667],
#          ...,
#          [-0.89322917],
#          [-0.890625  ],
#          [-0.88802083]],
#
#         [[-0.88020833],
#          [-0.87760417],
#          [-0.87760417],
#          ...,
#          [-0.89322917],
#          [-0.89322917],
#          [-0.890625  ]],
#
#         [[-0.890625  ],
#          [-0.88020833],
#          [-0.88020833],
#          ...,
#          [-0.90104167],
#          [-0.89322917],
#          [-0.89322917]]],
#
#
#        [[[-0.7734375 ],
#          [-0.75520833],
#          [-0.765625  ],
#          ...,
#          [-0.15885417],
#          [-0.2265625 ],
#          [-0.29166667]],
#
#         [[-0.77604167],
#          [-0.77864583],
#          [-0.77864583],
#          ...,
#          [-0.171875  ],
#          [-0.25      ],
#          [-0.43229167]],
#
#         [[-0.80208333],
#          [-0.796875  ],
#          [-0.79427083],
#          ...,
#          [-0.11197917],
#          [-0.27604167],
#          [-0.37239583]],
#
#         ...,
#
#         [[-0.78385417],
#          [-0.47916667],
#          [-0.18229167],
#          ...,
#          [-0.68489583],
#          [-0.5703125 ],
#          [-0.44010417]],
#
#         [[-0.58854167],
#          [-0.39322917],
#          [-0.13020833],
#          ...,
#          [-0.62239583],
#          [-0.484375  ],
#          [-0.51302083]],
#
#         [[-0.2578125 ],
#          [-0.0625    ],
#          [ 0.17708333],
#          ...,
#          [-0.484375  ],
#          [-0.36197917],
#          [-0.48697917]]]])

# %%
i = random.randint(1, len(x_train_gray))
plt.imshow(x_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(x_train[i])
plt.figure()
plt.imshow(x_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models
CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5,5), activation='relu', input_shape=(32, 32, 1)))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Dropout(0.2))

CNN.add(layers.Conv2D(16, (5,5), activation='relu'))
CNN.add(layers.AveragePooling2D())


CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation='relu'))
CNN.add(layers.Dense(84, activation='relu'))
CNN.add(layers.Dense(43, activation='softmax'))
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'Adam',loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(x_train_gray_norm,
                  y_train, batch_size = 400,
                  epochs = 25,
                  verbose = 1,
                  validation_data = (x_validation_gray_norm, y_validation)
                 )
# Out:
# Epoch 1/25
# 87/87 [==============================] - 5s 54ms/step - loss: 3.0527 - accuracy: 0.2012 - val_loss: 2.3510 - val_accuracy: 0.3537
# Epoch 2/25
# 87/87 [==============================] - 5s 52ms/step - loss: 1.5125 - accuracy: 0.5662 - val_loss: 1.2654 - val_accuracy: 0.6141
# Epoch 3/25
# 87/87 [==============================] - 5s 53ms/step - loss: 0.8958 - accuracy: 0.7411 - val_loss: 0.8625 - val_accuracy: 0.7492
# Epoch 4/25
# 87/87 [==============================] - 5s 54ms/step - loss: 0.6714 - accuracy: 0.8089 - val_loss: 0.7005 - val_accuracy: 0.7927
# Epoch 5/25
# 87/87 [==============================] - 5s 53ms/step - loss: 0.5440 - accuracy: 0.8487 - val_loss: 0.6327 - val_accuracy: 0.8175
# Epoch 6/25
# 87/87 [==============================] - 5s 52ms/step - loss: 0.4632 - accuracy: 0.8711 - val_loss: 0.5866 - val_accuracy: 0.8304
# Epoch 7/25
# 87/87 [==============================] - 5s 53ms/step - loss: 0.3991 - accuracy: 0.8890 - val_loss: 0.5676 - val_accuracy: 0.8363
# Epoch 8/25
# 87/87 [==============================] - 5s 53ms/step - loss: 0.3421 - accuracy: 0.9065 - val_loss: 0.5018 - val_accuracy: 0.8571
# Epoch 9/25
# 87/87 [==============================] - 5s 53ms/step - loss: 0.3057 - accuracy: 0.9146 - val_loss: 0.4696 - val_accuracy: 0.8773
# Epoch 10/25
# 87/87 [==============================] - 5s 53ms/step - loss: 0.2745 - accuracy: 0.9241 - val_loss: 0.4743 - val_accuracy: 0.8587
# Epoch 11/25
# 87/87 [==============================] - 5s 55ms/step - loss: 0.2507 - accuracy: 0.9320 - val_loss: 0.4272 - val_accuracy: 0.8855
# Epoch 12/25
# 87/87 [==============================] - 5s 56ms/step - loss: 0.2262 - accuracy: 0.9379 - val_loss: 0.4416 - val_accuracy: 0.8816
# Epoch 13/25
# 87/87 [==============================] - 5s 55ms/step - loss: 0.2082 - accuracy: 0.9423 - val_loss: 0.3970 - val_accuracy: 0.8918
# Epoch 14/25
# 87/87 [==============================] - 5s 55ms/step - loss: 0.1883 - accuracy: 0.9479 - val_loss: 0.3789 - val_accuracy: 0.9025
# Epoch 15/25
# 87/87 [==============================] - 5s 56ms/step - loss: 0.1709 - accuracy: 0.9530 - val_loss: 0.3659 - val_accuracy: 0.9059
# Epoch 16/25
# 87/87 [==============================] - 5s 54ms/step - loss: 0.1606 - accuracy: 0.9557 - val_loss: 0.4004 - val_accuracy: 0.9025
# Epoch 17/25
# 87/87 [==============================] - 5s 55ms/step - loss: 0.1448 - accuracy: 0.9609 - val_loss: 0.3568 - val_accuracy: 0.9084
# Epoch 18/25
# 87/87 [==============================] - 5s 54ms/step - loss: 0.1350 - accuracy: 0.9630 - val_loss: 0.3722 - val_accuracy: 0.9066
# Epoch 19/25
# 87/87 [==============================] - 5s 54ms/step - loss: 0.1273 - accuracy: 0.9657 - val_loss: 0.3587 - val_accuracy: 0.9102
# Epoch 20/25
# 87/87 [==============================] - 5s 55ms/step - loss: 0.1187 - accuracy: 0.9671 - val_loss: 0.3746 - val_accuracy: 0.8975
# Epoch 21/25
# 87/87 [==============================] - 5s 57ms/step - loss: 0.1135 - accuracy: 0.9686 - val_loss: 0.3541 - val_accuracy: 0.9116
# Epoch 22/25
# 87/87 [==============================] - 5s 56ms/step - loss: 0.1027 - accuracy: 0.9716 - val_loss: 0.3629 - val_accuracy: 0.9152
# Epoch 23/25
# 87/87 [==============================] - 5s 56ms/step - loss: 0.0970 - accuracy: 0.9730 - val_loss: 0.3515 - val_accuracy: 0.9104
# Epoch 24/25
# 87/87 [==============================] - 5s 58ms/step - loss: 0.0958 - accuracy: 0.9735 - val_loss: 0.3595 - val_accuracy: 0.9104
# Epoch 25/25
# 87/87 [==============================] - 5s 57ms/step - loss: 0.0878 - accuracy: 0.9759 - val_loss: 0.3801 - val_accuracy: 0.9043

# %% [markdown]
# # ASSESS TRAINED CNN MODEL PERFORMANCE

# %%
score = CNN.evaluate(x_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.5747 - accuracy: 0.9016
# Test Accuracy: 0.9015835523605347

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'ro', label='Training acc')
plt.plot(epochs, val_accuracy, 'r', label='Validation acc')

# %%
predicted_classes = CNN.predict_classes(x_test_gray_norm)
y_true = y_test

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (20, 20))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(x_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %% [markdown]
# # APPENDIX

# %% [markdown]
# - In this case study, we want to classify images of traffic signs using deep Convolutional Neural Networks (CNNs).
# - The dataset consists of 43 different classes of images.
# - Classes are as listed below:
#   - 0 = Speed limit (20km/h)
#   - 1 = Speed limit (30km/h)
#   - 2 = Speed limit (50km/h)
#   - 3 = Speed limit (60km/h)
#   - 4 = Speed limit (70km/h)
#   - 5 = Speed limit (80km/h)
#   - 6 = End of speed limit (80km/h)
#   - 7 = Speed limit (100km/h)
#   - 8 = Speed limit (120km/h)
#   - 9 = No passing
#   - 10 = No passing for vehicles over 3.5 metric tons
#   - 11 = Right-of-way at the next intersection
#   - 12 = Priority road
#   - 13 = Yield
#   - 14 = Stop
#   - 15 = No vehicles
#   - 16 = Vehicles over 3.5 metric tons prohibited
#   - 17 = No entry
#   - 18 = General caution
#   - 19 = Dangerous curve to the left
#   - 20 = Dangerous curve to the right
#   - 21 = Double curve
#   - 22 = Bumpy road
#   - 23 = Slippery road
#   - 24 = Road narrows on the right
#   - 25 = Road work
#   - 26 = Traffic signals
#   - 27 = Pedestrians
#   - 28 = Children crossing
#   - 29 = Bicycles crossing
#   - 30 = Beware of ice/snow
#   - 31 = Wild animals crossing
#   - 32 = End of all speed and passing limits
#   - 33 = Turn right ahead
#   - 34 = Turn left ahead
#   - 35 = Ahead only
#   - 36 = Go straight or right
#   - 37 = Go straight or left
#   - 38 = Keep right
#   - 39 = Keep left
#   - 40 = Roundabout mandatory
#   - 41 = End of no passing
#   - 42 = End of no passing by vehicles over 3.5 metric tons
